# %%
class Node:
    def __init__(self,data, previous_node_address=None,next_node_address=None):
        self.data = data
        self.previous_node_address = previous_node_address
        self.next_node_address = next_node_address
