# %%
import array as arr 

a = arr.array("i",[21,16])

print(a)
# Out:
# array('i', [21, 16])

# %%
copyArray = arr.array(a.typecode,[x for x in a])

# %%
print(copyArray)
for i in copyArray:
    print(i, end =" ")
# Out:
# array('i', [21, 16])
# 21 16

# %%
import numpy as np 

b = np.linspace(16,21,2)

# %%
b
# Out:
# array([16., 21.])

# %%
c = np.arange(10,20,2)

# %%
c
# Out:
# array([10, 12, 14, 16, 18])

# %%
d = np.full(4,5)

# %%
d
# Out:
# array([5, 5, 5, 5])
